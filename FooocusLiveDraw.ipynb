# %% [markdown]
# <a href="https://colab.research.google.com/github/DonMilcrypto/DonMilcrypto/blob/main/FooocusLiveDraw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python and Git are already installed in Google Colab.
# To use Conda (Anaconda), we install condacolab:
# !pip install -q condacolab
import condacolab
condacolab.install()

# %%
# !git clone https://github.com/brayevalerien/Fooocus-Lite

# %%
# %cd Fooocus-Lite
# !conda create -n flite python=3.10.11 -y

# %%
# !conda activate flite
# !pip install -r requirements.txt

# %%
# !pip3 install torch torchvision --index-url https://download.pytorch.org/whl/cu126

# %%
# %cd /content/Fooocus-Lite

# %%
# !MPLBACKEND=Agg python start.py --share
